# %% [markdown]
# # Train a YOLO Model on Satellite Images

# %% [markdown]
# ### Setup / Init

# %%
import os
import torch
import wandb
from ultralytics import YOLO, settings

# %%
# print torch and cuda version
# !nvcc --version

print(f"Torch version: {torch.__version__}")
print(f"Cuda available: {torch.cuda.is_available()}")
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Wed_Oct_30_01:18:48_Pacific_Daylight_Time_2024
# Cuda compilation tools, release 12.6, V12.6.85
# Build cuda_12.6.r12.6/compiler.35059454_0
# Torch version: 2.9.0+cu126
# Cuda available: True

# %%
# !yolo settings wandb=True
# Out:
# JSONDict("C:\Users\Raffael\AppData\Roaming\Ultralytics\settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "c:\\code\\cassda-zertifikatsarbeit/data",
#   "weights_dir": "c:\\code\\cassda-zertifikatsarbeit/model/weights",
#   "runs_dir": "c:\\code\\cassda-zertifikatsarbeit/model/runs",
#   "uuid": "d3a7ce3cd9801abab807540a7187a68d86586ced91ac34644efaccb296e135be",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": true,
#   "vscode_msg": true
# }
# 💡 Learn more about Ultralytics Settings at https://docs.ultralytics.com/quickstart/#ultralytics-settings

# %%
# Update a setting
settings.update(
    {
        "runs_dir": f"{os.path.dirname(os.getcwd())}/model/runs",
        "weights_dir": f"{os.path.dirname(os.getcwd())}/model/weights",
        "datasets_dir": f"{os.path.dirname(os.getcwd())}/data",
    }
)

# %% [markdown]
# ### Execution

# %%
model = YOLO(
    "../model/checkpoints/yolo11n-obb.pt"
)  # yolov11n-obb.pt is a model pre-trained on DOTA dataset for oriented bounding boxes

# %%
results = model.train(
    data="../data/combined_wildlife_poly_bridges_filtered_no_ch_640-yolo/data.yaml",
    epochs=1000,
    imgsz=640,
    patience=10,  # stop after 10 epochs without improvement on val mAP
    project="cassda-wildlife-crossing",
    name="yolo11n-obb-wildlife_bridges-filtered-dataset-no-CH-negatives-640",
    exist_ok=True,
    plots=True,
    translate=0.4,  # fraction of image size
    degrees=90,
    scale=0.5,  # scaling factor
    fliplr=0.5,  # horizontal flip probability
    flipud=0.5,  # vertical flip probability
)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 322
# New https://pypi.org/project/ultralytics/8.3.228 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40  Python-3.13.1 torch-2.9.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 16376MiB)
# engine\trainer: task=obb, mode=train, model=../model/checkpoints/yolo11n-obb.pt, data=../data/combined_wildlife_poly_bridges_filtered_no_ch_640-yolo/data.yaml, epochs=1000, time=None, patience=10, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=cassda-wildlife-crossing, name=yolo11n-obb-wildlife_bridges-filtered-dataset-no-CH-negatives-640, exist_ok=True, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=90, translate=0.4, scale=0.5, shear=0.0, perspective=0.0, flipud=0.5, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=cassda-wildlife-crossing\yolo11n-obb-wildlife_bridges-filtered-dataset-no-CH-negatives-640
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    502534  ultralytics.nn.modules.head.OBB              [1, 1, [64, 128, 256]]
# YOLO11n-obb summary: 344 layers, 2,661,702 parameters, 2,661,686 gradients, 6.7 GFLOPs
#
# Transferred 535/541 items from pretrained weights
# wandb: Currently logged in as: raffael-schreiber (fhnw-ibre) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>c:\code\cassda-zertifikatsarbeit\notebooks\wandb\run-20251112_172412-qasblakc</code>
# Syncing run <strong><a href='https://wandb.ai/fhnw-ibre/cassda-wildlife-crossing/runs/qasblakc' target="_blank">yolo11n-obb-wildlife_bridges-filtered-dataset-no-CH-negatives-640</a></strong> to <a href='https://wandb.ai/fhnw-ibre/cassda-wildlife-crossing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/fhnw-ibre/cassda-wildlife-crossing' target="_blank">https://wandb.ai/fhnw-ibre/cassda-wildlife-crossing</a>
#  View run at <a href='https://wandb.ai/fhnw-ibre/cassda-wildlife-crossing/runs/qasblakc' target="_blank">https://wandb.ai/fhnw-ibre/cassda-wildlife-crossing/runs/qasblakc</a>
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 28.8MB/s]
# AMP: checks passed
# train: Scanning C:\code\cassda-zertifikatsarbeit\data\combined_wildlife_poly_bridges_filtered_no_ch_640-yolo\labels\train... 387 images, 60 backgrounds, 0 corrupt: 100%|██████████| 387/387 [00:00<00:00, 397.74it/s]
# train: New cache created: C:\code\cassda-zertifikatsarbeit\data\combined_wildlife_poly_bridges_filtered_no_ch_640-yolo\labels\train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# c:\code\cassda-zertifikatsarbeit\.venv\Lib\site-packages\ultralytics\data\augment.py:1850: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0),
# val: Scanning C:\code\cassda-zertifikatsarbeit\data\combined_wildlife_poly_bridges_filtered_no_ch_640-yolo\labels\val... 82 images, 12 backgrounds, 0 corrupt: 100%|██████████| 82/82 [00:00<00:00, 1385.49it/s]
# val: New cache created: C:\code\cassda-zertifikatsarbeit\data\combined_wildlife_poly_bridges_filtered_no_ch_640-yolo\labels\val.cache
# Plotting labels to cassda-wildlife-crossing\yolo11n-obb-wildlife_bridges-filtered-dataset-no-CH-negatives-640\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to cassda-wildlife-crossing\yolo11n-obb-wildlife_bridges-filtered-dataset-no-CH-negatives-640
# Starting training for 1000 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      1/1000       2.5G      2.394      11.31       1.96          2        640: 100%|██████████| 25/25 [00:22<00:00,  1.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:08<00:00,  1.46s/it]
#                    all         82         70      0.401        0.3      0.332     0.0981
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      2/1000      2.49G      1.812      4.515      1.446          2        640: 100%|██████████| 25/25 [00:04<00:00,  5.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.90it/s]
#                    all         82         70      0.472      0.586      0.486      0.254
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      3/1000      2.51G      1.724      2.249      1.729          3        640: 100%|██████████| 25/25 [00:04<00:00,  6.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:00<00:00,  6.20it/s]
#                    all         82         70      0.817      0.671      0.751      0.381
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      4/1000       2.5G      1.751      1.741      1.596          2        640: 100%|██████████| 25/25 [00:04<00:00,  5.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:00<00:00,  6.37it/s]
#                    all         82         70      0.754      0.857      0.847       0.42
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      5/1000      2.49G      1.662       1.31      1.606          3        640: 100%|██████████| 25/25 [00:04<00:00,  5.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:00<00:00,  7.21it/s]
#                    all         82         70       0.75      0.829      0.774      0.382
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      6/1000       2.5G      1.687      1.215      1.694          3        640: 100%|██████████| 25/25 [00:03<00:00,  6.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:00<00:00,  6.99it/s]
#                    all         82         70      0.822      0.729      0.774      0.399
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      7/1000       2.5G      1.623      1.143      1.591          5        640: 100%|██████████| 25/25 [00:03<00:00,  6.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:00<00:00,  6.84it/s]
#                    all         82         70      0.822        0.7      0.743      0.335
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      8/1000       2.5G      1.685      1.104      1.614          3        640: 100%|██████████| 25/25 [00:03<00:00,  6.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:00<00:00,  6.88it/s]
#                    all         82         70      0.875      0.897       0.87      0.447
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      9/1000      2.49G      1.658      1.153      1.678          3        640: 100%|██████████| 25/25 [00:04<00:00,  6.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:00<00:00,  6.10it/s]
#                    all         82         70      0.878      0.823      0.865      0.477
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     10/1000       2.5G      1.651      1.202      1.607          1        640: 100%|██████████| 25/25 [00:04<00:00,  5.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  5.70it/s]
#                    all         82         70      0.819      0.814      0.847      0.464
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     11/1000       2.5G      1.604      1.064      1.579          3        640: 100%|██████████| 25/25 [00:04<00:00,  5.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:00<00:00,  6.70it/s]
#                    all         82         70      0.791      0.886      0.879       0.46
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     12/1
32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:04<00:00,  1.33it/s]
#                    all         82         70      0.907      0.943      0.929      0.485
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     50/1000      2.51G      1.456     0.8118      1.466          5        640: 100%|██████████| 25/25 [00:15<00:00,  1.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.43it/s]
#                    all         82         70      0.887      0.886      0.872      0.494
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 40, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 50 epochs completed in 0.193 hours.
# Optimizer stripped from cassda-wildlife-crossing\yolo11n-obb-wildlife_bridges-filtered-dataset-no-CH-negatives-640\weights\last.pt, 5.7MB
# Optimizer stripped from cassda-wildlife-crossing\yolo11n-obb-wildlife_bridges-filtered-dataset-no-CH-negatives-640\weights\best.pt, 5.7MB
#
# Validating cassda-wildlife-crossing\yolo11n-obb-wildlife_bridges-filtered-dataset-no-CH-negatives-640\weights\best.pt...
# Ultralytics 8.3.40  Python-3.13.1 torch-2.9.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4070 Ti SUPER, 16376MiB)
# YOLO11n-obb summary (fused): 257 layers, 2,653,918 parameters, 0 gradients, 6.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<00:00,  4.04it/s]
#                    all         82         70      0.885      0.883      0.875      0.538
# Speed: 0.8ms preprocess, 1.8ms inference, 0.0ms loss, 4.5ms postprocess per image
# Results saved to cassda-wildlife-crossing\yolo11n-obb-wildlife_bridges-filtered-dataset-no-CH-negatives-640
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>▁▃▆█████████████████████████████████████</td></tr><tr><td>lr/pg1</td><td>▁▃▆█████████████████████████████████████</td></tr><tr><td>lr/pg2</td><td>▁▃▆█████████████████████████████████████</td></tr><tr><td>metrics/mAP50(B)</td><td>▁▃▆▇▆▆▇▇▇▇▇▇▇▇▇▇▇▇███▇███▇▇▇▇▇▇█▇███▇██▇</td></tr><tr><td>metrics/mAP50-95(B)</td><td>▁▃▅▆▆▅▇▇▇▇▇▇▇▆▇▇▇▇█▇▇▇█▇▇▇▇▆▇▇███▇██████</td></tr><tr><td>metrics/precision(B)</td><td>▁▂▇▆▆▇▇▇▆▇▆▆▇▇▇▇▇█▇██████▇█▇▇███████▇███</td></tr><tr><td>metrics/recall(B)</td><td>▁▄▅▇▇▅▇▇▇▇▇▇▇▆▆▆▆▇▆███▇▇▇█▇▇▇▇█▇▇▇▇▇▇█▇█</td></tr><tr><td>model/GFLOPs</td><td>▁</td></tr><tr><td>model/parameters</td><td>▁</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>▁</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>lr/pg0</td><td>0.0019</td></tr><tr><td>lr/pg1</td><td>0.0019</td></tr><tr><td>lr/pg2</td><td>0.0019</td></tr><tr><td>metrics/mAP50(B)</td><td>0.87483</td></tr><tr><td>metrics/mAP50-95(B)</td><td>0.53813</td></tr><tr><td>metrics/precision(B)</td><td>0.88535</td></tr><tr><td>metrics/recall(B)</td><td>0.88253</td></tr><tr><td>model/GFLOPs</td><td>6.688</td></tr><tr><td>model/parameters</td><td>2661702</td></tr><tr><td>model/speed_PyTorch(ms)</td><td>63.005</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">yolo11n-obb-wildlife_bridges-filtered-dataset-no-CH-negatives-640</strong> at: <a href='https://wandb.ai/fhnw-ibre/cassda-wildlife-crossing/runs/qasblakc' target="_blank">https://wandb.ai/fhnw-ibre/cassda-wildlife-crossing/runs/qasblakc</a><br> View project at: <a href='https://wandb.ai/fhnw-ibre/cassda-wildlife-crossing' target="_blank">https://wandb.ai/fhnw-ibre/cassda-wildlife-crossing</a><br>Synced 4 W&B file(s), 17 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251112_172412-qasblakc\logs</code>
